# %%
#Project Goal: The greatest NBA Player of All Time
import pandas as pd

# %%
#championship difficulty 
https://www.reddit.com/r/nba/comments/jj6vk1/playoff_success_of_the_mvp_and_runner_up_since/
# Out:
#   Cell In[3], line 2
#     https://www.reddit.com/r/nba/comments/jj6vk1/playoff_success_of_the_mvp_and_runner_up_since/
#           ^
# SyntaxError: invalid syntax

# %%
pd.read_csv("play_by_play.csv")
# Out:
#            game_id  eventnum  eventmsgtype  eventmsgactiontype  period  \
# 0         29600012         0            12                   0       1
# 1         29600012         2            10                   0       1
# 2         29600012         3             2                   1       1
# 3         29600012         4             4                   0       1
# 4         29600012         5             2                   1       1
# ...            ...       ...           ...                 ...     ...
# 13592894  32200001       638             1                  79       4
# 13592895  32200001       639             2                   1       4
# 13592896  32200001       640             4                   0       4
# 13592897  32200001       641             1                  79       4
# 13592898  32200001       642            13                   0       4
#
#          wctimestring pctimestring  \
# 0            14:43 PM        12:00
# 1            14:50 PM        12:00
# ...

# %%
pd.read_csv("player.csv")
# Out:
#            id            full_name first_name     last_name  is_active
# 0       76001       Alaa Abdelnaby       Alaa     Abdelnaby          0
# 1       76002      Zaid Abdul-Aziz       Zaid    Abdul-Aziz          0
# 2       76003  Kareem Abdul-Jabbar     Kareem  Abdul-Jabbar          0
# 3          51   Mahmoud Abdul-Rauf    Mahmoud    Abdul-Rauf          0
# 4        1505    Tariq Abdul-Wahad      Tariq   Abdul-Wahad          0
# ...       ...                  ...        ...           ...        ...
# 4826  1627790           Ante Zizic       Ante         Zizic          0
# 4827    78647             Jim Zoet        Jim          Zoet          0
# 4828    78648            Bill Zopf       Bill          Zopf          0
# 4829  1627826          Ivica Zubac      Ivica         Zubac          1
# 4830    78650           Matt Zunic       Matt         Zunic          0
#
# [4831 rows x 5 columns]

# %%
#number of champions
#difficulty of championships
#MVPS
#FinalsMVPs
#DPOY
#Points per game
#Career plus minus
#

# %%
players = pd.read_csv("Seasons_Stats.csv")

# %%
players.groupby("Year").mean()
# Out:
# /var/folders/y4/ty9_pcns397b4slfvgp240kw0000gn/T/ipykernel_19923/2209964813.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   players.groupby("Year").mean()
#         Unnamed: 0        Age          G         GS           MP        PER  \
# Year
# 1950.0       155.5  26.131410  42.884615        NaN          NaN        NaN
# 1951.0       399.5  26.344828  43.890805        NaN          NaN        NaN
# 1952.0       552.5  26.130769  49.415385        NaN  1294.792308  12.511811
# 1953.0       698.5  26.018868  45.725000        NaN  1201.581250  11.698742
# 1954.0       845.0  25.769231  49.862595        NaN  1278.458015  11.893798
# ...            ...        ...        ...        ...          ...        ...
# 2013.0     21965.0  26.535777  49.219895  22.499127  1112.923211  12.127972
# ...

# %%
players.columns
# Out:
# Index(['Unnamed: 0', 'Year', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP',
#        'PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%',
#        'BLK%', 'TOV%', 'USG%', 'blanl', 'OWS', 'DWS', 'WS', 'WS/48', 'blank2',
#        'OBPM', 'DBPM', 'BPM', 'VORP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB',
#        'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
pd.read_csv("18-19.csv")
# Out:
#     Unnamed: 0                     Player  Pos   Age   Tm     G    GS      MP  \
# 0            1               Alex Abrines   SG  25.0  OKC  31.0   2.0   588.0
# 1            2                 Quincy Acy   PF  28.0  PHO  10.0   0.0   123.0
# 2            3               Jaylen Adams   PG  22.0  ATL  34.0   1.0   428.0
# 3            4               Steven Adams    C  25.0  OKC  80.0  80.0  2669.0
# 4            5                Bam Adebayo    C  21.0  MIA  82.0  28.0  1913.0
# ..         ...                        ...  ...   ...  ...   ...   ...     ...
# 704        529  Ante \'8ei\'9ei\uc0\u263     C  22.0  CLE  59.0  25.0  1082.0
# 705        530                Ivica Zubac    C  21.0  TOT  59.0  37.0  1040.0
# 706        530                Ivica Zubac    C  21.0  LAL  33.0  12.0   516.0
# 707        530                Ivica Zubac    C  21.0  LAC  26.0  25.0   524.0
# 708          }                        NaN  NaN   NaN  NaN   NaN   NaN     NaN
#
# ...
